# %%
#OPENCV PROJECT-2

# %%
#import packages
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %matplotlib inline

# %%
#read in 3D array
img1 = cv2.imread('/home/sunbeam/Documents/gitdata/ML/day10_13dec/images/messi5.jpg')
img2 = cv2.imread('/home/sunbeam/Documents/gitdata/ML/day10_13dec/images/messi5.jpg',cv2.IMREAD_GRAYSCALE)

# %%
#plot the files
plt.imshow(img1)

# %%
#plot the files
plt.imshow(img2)

# %%
#show image
cv2.imshow('messi-color',img1)
cv2.imshow('messi-gray',img2)
key = cv2.waitKey(0)
cv2.destroyAllWindows()
