# %%
#OPENCV PROJECT-9

# %%
#import packages
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %matplotlib inline

# %%
img = cv2.imread('/home/sunbeam/Documents/gitdata/ML/day10_13dec/images/messi5.jpg')

# %%
from IPython.display import Image, display

listOfImageNames = ['/home/sunbeam/Documents/gitdata/ML/day10_13dec/images/messi5.jpg']

for imageName in listOfImageNames:
    display(Image(filename=imageName))

# %%
# cropping the face
# (200, 60), (275, 150)
face = img[60:150, 200:275]

# %%
# cropping the football
# (330, 285), (400, 340)
football = img[285:340, 330:400]

# %%
no_football = img[280:335, 140:210].copy()

# %%
# pasting the football to some other location
# (160, 275), (230, 330)
img[280:335, 140:210] = football
img[285:340, 330:400] = no_football

# %%
cv2.imshow('messi', img)
cv2.imwrite('/tmp/messi_football_kick.jpg', img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from IPython.display import Image, display

listOfImageNames = ['/tmp/messi_football_kick.jpg']

for imageName in listOfImageNames:
    display(Image(filename=imageName))
