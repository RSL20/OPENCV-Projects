# %%
# OPENCV PROJECT-1

# %%
#import packages
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %matplotlib inline

# %%
#read a file into 3D array
img = cv2.imread('/home/sunbeam/Documents/gitdata/ML/day10_13dec/images/messi5.jpg')

# %%
plt.imshow(img)

# %%
print(img)
# Out:
# [[[ 39  43  44]
#   [ 42  46  47]
#   [ 44  47  52]
#   ...
#   [ 57  55  55]
#   [ 55  53  53]
#   [ 52  50  50]]
#
#  [[ 37  40  44]
#   [ 42  45  49]
#   [ 46  49  54]
#   ...
#   [ 62  60  60]
#   [ 60  58  58]
#   [ 57  55  55]]
#
#  [[ 41  45  50]
#   [ 46  50  55]
#   [ 51  55  60]
#   ...
#   [ 64  63  65]
#   [ 63  62  64]
#   [ 60  59  61]]
#
#  ...
#
#  [[ 56 143  99]
#   [ 48 133  89]
#   [ 49 129  86]
#   ...
#   [ 60 134  92]
#   [ 63 134  94]
#   [ 73 145 103]]
#
#  [[ 54 138  96]
#   [ 59 141  99]
#   [ 50 130  87]
#   ...
#   [ 56 132  91]
#   [ 69 142 104]
#   [ 64 137  97]]
#
#  [[ 45 129  87]
#   [ 58 140  98]
#   [ 71 151 108]
#   ...
#   [ 49 124  86]
#   [ 52 125  87]
#   [ 51 124  86]]]

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img.shape)
# Out:
# (342, 548, 3)

# %%
print(f"Height: {img.shape[0]}, Width: {img.shape[1]}, channels: {img.shape[2]}")
# Out:
# Height: 342, Width: 548, channels: 3

# %%
(h,w,d) = img.shape
print(f"Height: {h}, Width: {w}, Channels: {d}")
# Out:
# Height: 342, Width: 548, Channels: 3

# %%
print(img[0,0])
print(img[316,371])
# Out:
# [39 43 44]
# [ 93 252 242]
